# %%
## Business case:-On the basis of given parameters(features) our
#target is to find
## whether a patient will have B type or M type cancer.
## So we are solving a classifcation task.

# %%
## importing the libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
data = pd.read_csv('/content/breast_cancer (1).csv')
print(data.shape)
data.head()
# Out:
# (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
## basic checks
## head,tail,describe,info,missing value(is null),check if any categorical data
## unique,value_counts.
## Plotting and getting insights from data(univariate analysis,bivariate
## and multivariate analysis)(matplotlib and seaborn)
## Feature selection:-Heatmap

# %%
## creating independent and dependent variables
X = data.iloc[:,2:-1]
y = data.diagnosis

# %%
data.head(1)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
#
#    fractal_dimension_worst  Unnamed: 32
# 0                   0.1189          NaN
#
# [1 rows x 33 columns]

# %%
## Scaling the data as the magnitude of variables are varying lot
from sklearn.preprocessing import StandardScaler
sc=StandardScaler() ## object creation
sclaed_x=sc.fit_transform(X) ## transforming the data
X = pd.DataFrame(sclaed_x,columns=X.columns) ##converting the arrays
## to dataframe

# %%
##creating training and test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,
                                test_size=0.2,random_state=10)

# %%
## check train and test data

# %%
## model creation
from sklearn.neural_network import MLPClassifier
model = MLPClassifier( hidden_layer_sizes=(50,3),
                       learning_rate_init=0.1,
                       max_iter=100,
                       random_state=2) ## model object creation max_iter=Stopping parameter
model.fit(X_train,y_train) ## training the data
y_predict_proba = model.predict_proba(X_test) ## predicting the pro
## bability of class
y_predict = model.predict(X_test)
y_train_predict = model.predict(X_train)

# %%
## Evaluating the model created
from sklearn.metrics import accuracy_score,confusion_matrix
print("Train accuracy :",accuracy_score(y_train,y_train_predict))
print("Test accuracy :",accuracy_score(y_test,y_predict))
# Out:
# Train accuracy : 0.9934065934065934
# Test accuracy : 0.9736842105263158

# %%
## getting the confusion matrix
pd.crosstab(y_test,y_predict)
# Out:
# col_0       B   M
# diagnosis
# B          75   0
# M           3  36

# %%
from zipfile import ZipFile
file_name="/content/archive (8).zip"
with ZipFile(file_name,'r')as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np

BASE_DIR = '/content/PetImages'
cat_dir = os.path.join(BASE_DIR, 'Cat')
dog_dir = os.path.join(BASE_DIR, 'Dog')

cat_files_raw = [os.path.join(cat_dir, f) for f in os.listdir(cat_dir)]
dog_files_raw = [os.path.join(dog_dir, f) for f in os.listdir(dog_dir)]

print(f"Cat: {len(cat_files_raw)} archivos")
print(f"Dog: {len(dog_files_raw)} archivos")
# Out:
# Cat: 12499 archivos
# Dog: 12499 archivos

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
path = "/content/PetImages"

cat_path = os.path.join(path, "Cat")
dog_path = os.path.join(path, "Dog")

# %%
cat_images = os.listdir(cat_path)
dog_images = os.listdir(dog_path)

print("Number of Cat Images :", len(cat_images))
print("Number of Dog Images :", len(dog_images))
# Out:
# Number of Cat Images : 12499
# Number of Dog Images : 12499

# %%
data = []

# Cats
for image in cat_images:
    data.append([os.path.join(cat_path, image), 0])

# Dogs
for image in dog_images:
    data.append([os.path.join(dog_path, image), 1])

print("Total Images :", len(data))
# Out:
# Total Images : 24998

# %%
import pandas as pd

df = pd.DataFrame(data, columns=["filepath", "label"])

df.head()
# Out:
#                           filepath  label
# 0   /content/PetImages/Cat/842.jpg      0
# 1  /content/PetImages/Cat/5196.jpg      0
# 2  /content/PetImages/Cat/1857.jpg      0
# 3  /content/PetImages/Cat/7131.jpg      0
# 4  /content/PetImages/Cat/6876.jpg      0

# %%
df = df.sample(frac=1, random_state=42)

df.head()
# Out:
#                               filepath  label
# 6868   /content/PetImages/Cat/7074.jpg      0
# 22910  /content/PetImages/Dog/6233.jpg      1
# 9668   /content/PetImages/Cat/1576.jpg      0
# 13638  /content/PetImages/Dog/1019.jpg      1
# 23337  /content/PetImages/Dog/5872.jpg      1

# %%
df = df.sample(frac=1, random_state=42)

df.head()
# Out:
#                                filepath  label
# 888    /content/PetImages/Cat/10183.jpg      0
# 19124   /content/PetImages/Dog/1877.jpg      1
# 6443    /content/PetImages/Cat/8343.jpg      0
# 19057   /content/PetImages/Dog/7189.jpg      1
# 17764  /content/PetImages/Dog/11461.jpg      1

# %%
import matplotlib.pyplot as plt

for i in range(6):

    img = tf.keras.preprocessing.image.load_img(df["filepath"].iloc[i],
                                                target_size=(128,128))

    plt.subplot(2,3,i+1)
    plt.imshow(img)

    if df["label"].iloc[i]==0:
        plt.title("Cat")
    else:
        plt.title("Dog")

    plt.axis("off")

plt.show()

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42
)

print("Training Images :", len(train_df))
print("Testing Images :", len(test_df))
# Out:
# Training Images : 19998
# Testing Images : 5000

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    target_size=(128,128),
    batch_size=32,
    class_mode="raw"
)
# Out:
# Found 19998 validated image filenames.

# %%
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    target_size=(128,128),
    batch_size=32,
    class_mode="raw"
)
# Out:
# Found 5000 validated image filenames.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# First Convolution Layer
model.add(Conv2D(32,
                 (3,3),
                 activation='relu',
                 input_shape=(128,128,3)))

model.add(MaxPooling2D(pool_size=(2,2)))

# Second Convolution Layer
model.add(Conv2D(64,
                 (3,3),
                 activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

# Third Convolution Layer
model.add(Conv2D(128,
                 (3,3),
                 activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten
model.add(Flatten())

# Hidden Layer
model.add(Dense(128, activation='relu'))

# Output Layer
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,304,769 (12.61 MB)
#  Trainable params: 3,304,769 (12.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=10
)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6563 - loss: 0.6076 - val_accuracy: 0.7550 - val_loss: 0.5011
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.7734 - loss: 0.4743 - val_accuracy: 0.7998 - val_loss: 0.4350
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.8214 - loss: 0.3959 - val_accuracy: 0.8158 - val_loss: 0.4077
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 67ms/step - accuracy: 0.8584 - loss: 0.3243 - val_accuracy: 0.8282 - val_loss: 0.3913
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 45s 71ms/step - accuracy: 0.8901 - loss: 0.2617 - val_accuracy: 0.8212 - val_loss: 0.4078
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.9256 - loss: 0.1859 - val_accuracy: 0.8378 - val_loss: 0.4036
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 67ms/step - accuracy: 0.9545 - loss: 0.1162 - val_accuracy: 0.8414 - val_loss: 0.4584
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 67ms/step - accuracy: 0.9675 - loss: 0.0828 - val_accuracy: 0.8280 - val_loss: 0.6121
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 66ms/step - accuracy: 0.9812 - loss: 0.0534 - val_accuracy: 0.8352 - val_loss: 0.5891
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 44s 71ms/step - accuracy: 0.9872 - loss: 0.0368 - val_accuracy: 0.8328 - val_loss: 0.8198

# %%
loss, accuracy = model.evaluate(test_generator)

print("Loss :", loss)
print("Accuracy :", accuracy)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8328 - loss: 0.8198
# Loss : 0.8198179602622986
# Accuracy : 0.8327999711036682

# %%
image_path = "/content/PetImages/Cat/1.jpg"   # change image path

img = tf.keras.preprocessing.image.load_img(
    image_path,
    target_size=(128,128)
)

img_array = tf.keras.preprocessing.image.img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

if prediction[0][0] > 0.5:
    print("Dog")
else:
    print("Cat")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# Cat
